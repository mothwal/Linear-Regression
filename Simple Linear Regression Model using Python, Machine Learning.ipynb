# %%
import warnings
warnings.filterwarnings('ignore')

#import the numpy and the pandas packege

import numpy as np
import pandas as pd

#read the cvs and view the records

advertising  = pd.read_csv('C:/Users/louis/Videos/Captures/Company_data.csv')
advertising
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# 5      8.7   48.9       75.0    7.2
# 6     57.5   32.8       23.5   11.8
# 7    120.2   19.6       11.6   13.2
# 8      8.6    2.1        1.0    4.8
# 9    199.8    2.6       21.2   15.6
# 10    66.1    5.8       24.2   12.6
# 11   214.7   24.0        4.0   17.4
# 12    23.8   35.1       65.9    9.2
# 13    97.5    7.6        7.2   13.7
# 14   204.1   32.9       46.0   19.0
# 15   195.4   47.7       52.9   22.4
# 16    67.8   36.6      114.0   12.5
# 17   281.4   39.6       55.8   24.4
# 18    69.2   20.5       18.3   11.3
# 19   147.3   23.9       19.1   14.6
# 20   218.4   27.7       53.4   18.0
# 21   237.4    5.1       23.5   17.5
# 22    13.2   15.9       49.6    5.6
# 23   228.3   16.9       26.2   20.5
# 24    62.3   12.6       18.3    9.7
# ...

# %%
#Shape our data
advertising.shape

#infor our data,...., we can see whether there are any null values in the data
advertising.info()

#describing our data .....we’ll see whether there is any sudden jump in the data’s values
advertising.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
# TV           200 non-null float64
# Radio        200 non-null float64
# Newspaper    200 non-null float64
# Sales        200 non-null float64
# dtypes: float64(4)
# memory usage: 6.3 KB
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# #### Visualizing the data

# %%
import matplotlib.pyplot as plt
import seaborn as sns


#using pairplot we visualize the data for correlation
sns.pairplot(advertising, x_vars = ['TV', 'Radio', 'Newspaper'], y_vars = 'Sales', size = 4, aspect = 1, kind = 'scatter')

plt.show()

# %%
# Visualizing the data using heatmap
sns.heatmap(advertising.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %% [markdown]
# ##### Performing Simple Linear Regression

# %%
#Create X and y

X = advertising['TV']
y = advertising['Sales']

# %%
#splititng the variables as trainging and testing

from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

# %%
X_train
# Out:
# 74     213.4
# 3      151.5
# 185    205.0
# 26     142.9
# 90     134.3
# 127     80.2
# 81     239.8
# 88      88.3
# 119     19.4
# 110    225.8
# 57     136.2
# 44      25.1
# 148     38.0
# 160    172.5
# 89     109.8
# 146    240.1
# 199    232.1
# 10      66.1
# 20     218.4
# 165    234.5
# 12      23.8
# 16      67.8
# 101    296.4
# 120    141.3
# 45     175.1
# 142    220.5
# 117     76.4
# 184    253.8
# 187    191.1
# 183    287.6
#        ...
# 129     59.6
# 159    131.7
# 132      8.4
# 108     13.1
# 155      4.1
# 130      0.7
# 86      76.3
# 93     250.9
# 137    273.7
# 144     96.2
# 58     210.8
# 60      53.5
# 107     90.4
# 143    104.6
# 198    283.6
# 34      95.7
# 14     204.1
# 66      31.5
# 53     182.6
# 98     289.7
# 180    156.6
# 94     107.4
# 138     43.0
# 176    248.4
# 79     116.0
# 87     110.7
# 103    187.9
# 67     139.3
# 24      62.3
# 8        8.6
# Name: TV, Length: 140, dtype: float64

# %%
y_train
# Out:
# 74     17.0
# 3      16.5
# 185    22.6
# 26     15.0
# 90     14.0
# 127    11.9
# 81     17.3
# 88     12.9
# 119     6.6
# 110    18.4
# 57     13.2
# 44      8.5
# 148    10.9
# 160    16.4
# 89     16.7
# 146    18.2
# 199    18.4
# 10     12.6
# 20     18.0
# 165    16.9
# 12      9.2
# 16     12.5
# 101    23.8
# 120    15.5
# 45     16.1
# 142    20.1
# 117     9.4
# 184    17.6
# 187    17.3
# 183    26.2
#        ...
# 129     9.7
# 159    12.9
# 132     5.7
# 108     5.3
# 155     3.2
# 130     1.6
# 86     12.0
# 93     22.2
# 137    20.8
# 144    12.3
# 58     23.8
# 60      8.1
# 107    12.0
# 143    10.4
# 198    25.5
# 34     11.9
# 14     19.0
# 66     11.0
# 53     21.2
# 98     25.4
# 180    15.5
# 94     11.5
# 138     9.6
# 176    20.2
# 79     11.0
# 87     16.0
# 103    19.7
# 67     13.4
# 24      9.7
# 8       4.8
# Name: Sales, Length: 140, dtype: float64

# %% [markdown]
# ##### Building and training the model

# %%
# Importing Statsmodels.api library from Stamodel package
import statsmodels.api as sm
#Adding a constant to a concept
X_train_sm = sm.add_constant(X_train)

# %%
#Fitting the regression Line using 'OLS'

lr = sm.OLS(y_train, X_train_sm).fit()

#Print the parameter
lr.params
# Out:
# const    6.948683
# TV       0.054546
# dtype: float64

# %%
# Performing a summary to list out all the different parameters of the regression line fitted
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     611.2
# Date:                Wed, 31 Mar 2021   Prob (F-statistic):           1.52e-52
# Time:                        15:22:15   Log-Likelihood:                -321.12
# No. Observations:                 140   AIC:                             646.2
# Df Residuals:                     138   BIC:                             652.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.9487      0.385     18.068      0.000       6.188       7.709
# ...

# %%
# Visualizing the regression line
plt.scatter(X_train, y_train)
plt.plot(X_train, 6.948 + 0.054*X_train, 'r')
plt.show()

# %% [markdown]
# #### Residual Analysis

# %%
# Predicting y_value using traingn data of X
y_train_pred = lr.predict( X_train_sm)

# Creating residuals from the y_train data and predicted y_data
res = (y_train - y_train_pred)

# %%
# Plotting the histogram using the residual values

# %%
fig = plt.figure()
sns.distplot(res, bins = 15)
plt.title('Error Treams', fontsize = 15)
plt.xlabel('y_train - y_train_pred', fontsize = 15)
plt.show()

# %%
# Looking for any patterns in the residuals

plt.scatter(X_train, res)
plt.show()

# %% [markdown]
# #### Predictions on the Test data or Evaluating the model

# %%
#adding a constant to X_train

X_train.sm = sm.add_constant(X_test)

# Predicting the y values corresponding to X_test_sm

y_test_pred = lr.predict(X_train.sm )

# Printing the first 15 predicted values
y_test_pred
# Out:
# 126     7.374140
# 104    19.941482
# 99     14.323269
# 92     18.823294
# 111    20.132392
# 167    18.228745
# 116    14.541452
# 96     17.726924
# 52     18.752384
# 69     18.774202
# 164    13.341445
# 124    19.466933
# 182    10.014155
# 154    17.192376
# 125    11.705073
# 196    12.086893
# 194    15.114182
# 177    16.232370
# 163    15.866914
# 31     13.106899
# 11     18.659656
# 73     14.006904
# 15     17.606923
# 41     16.603281
# 97     17.034193
# 128    18.965113
# 133    18.937840
# 82     11.055978
# 139    17.034193
# 123    13.663265
# 83     10.679613
# 65     10.712340
# 151    13.548719
# 162    17.225103
# 170     9.675971
# 77     13.521446
# 32     12.250530
# 173    16.134188
# 174    19.079659
# 85     17.486923
# 168    18.697838
# 112    16.532372
# 171    15.921460
# 181    18.866930
# 7      13.505083
# 46     11.841437
# 75      7.870506
# 28     20.519667
# 29     10.799613
# 195     9.032331
# 40     17.994198
# 153    16.292371
# ...

# %%
# Importing r2_square

from sklearn.metrics import r2_score

# Checking the R-squared value
r_squared = r2_score(y_test, y_test_pred)
r_squared
# Out:
# 0.7921031601245658

# %%
# Visualize the line on the test set
plt.scatter(X_test, y_test)
plt.plot(X_test, y_test_pred, 'r')
plt.show()

# %%
# Splitting the data into train and test
from sklearn.model_selection import train_test_split
X_train_lm, X_test_lm, y_train_lm, y_test_lm = train_test_split(X, y, train_size = 0.7, 
                                                                test_size = 0.3, random_state = 100)

# %%
# Shape of the train set without adding column
X_train_lm.shape

# Adding additional column to the train and test data
X_train_lm = X_train_lm.values.reshape(-1,1)
X_test_lm = X_test_lm.values.reshape(-1,1)

print(X_train_lm.shape)
print(X_test_lm.shape)
# Out:
# (140, 1)
# (60, 1)

# %%
from sklearn.linear_model import LinearRegression

# Creating an object of Linear Regression
lm = LinearRegression()

# Fit the model using .fit() method
lm.fit(X_train_lm, y_train_lm)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# Intercept value
print("Intercept :",lm.intercept_)

# Slope value
print('Slope :',lm.coef_)
# Out:
# Intercept : 6.948683200001357
# Slope : [0.05454575]

# %%
y_train_pred = lm.predict(X_train_lm)
y_test_pred = lm.predict(X_test_lm)

# Comparing the r2 value of both train and test data
print(r2_score(y_train,y_train_pred))
print(r2_score(y_test,y_test_pred))
# Out:
# 0.8157933136480389
# 0.7921031601245662
